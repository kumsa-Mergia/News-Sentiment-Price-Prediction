# %% [markdown]
# # META Data Analysis

# %%
import sys
import os
import pandas as pd
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))
from data_analysis import NewsAnalyzer

# %%
data_filepath = "../data/raw_analyst_ratings/raw_analyst_ratings.csv"
analyzer = NewsAnalyzer(data_filepath)
print("--- Loading Data ---")
analyzer.load_data()
# Out:
# --- Loading Data ---
# CSV file loaded successfully.

# %% [markdown]
# # Filter The Data by its Ticker Values

# %% [markdown]
# ### Store the original DataFrame from the analyzer

# %%
original_df = analyzer.df.copy() # Important: create a copy so you can restore it

# %% [markdown]
# ### Filter the data and assign it to 'meta_df'

# %%
meta_df = original_df[original_df["stock"] == "FB"].copy()
print("meta.head()")
print(meta_df.head())
print("\n")
# Out:
# meta.head()
#         Unnamed: 0                                           headline  \
# 473873      476431  As Expected: Fed Keeps Rates Unchanged and For...
# 473874      476432  Facebook, Snap Analyst Projects Q2 Revenue Ups...
# 473875      476433  Tech Stocks And FAANGS Strong Again To Start D...
# 473876      476434  Big Tech Reaches New Record Heights At The Sto...
# 473877      476435  Twitter, Square Will Mark Juneteenth As Holida...
#
#                                                       url          publisher  \
# 473873  https://www.benzinga.com/news/20/06/16226512/a...         JJ Kinahan
# 473874  https://www.benzinga.com/analyst-ratings/analy...   Shanthi Rexaline
# 473875  https://www.benzinga.com/government/20/06/1622...         JJ Kinahan
# 473876  https://www.benzinga.com/news/20/06/16218615/b...      Neer Varshney
# 473877  https://www.benzinga.com/news/20/06/16218441/t...  Shivdeep Dhaliwal
#
#                              date stock
# 473873  2020-06-10 16:20:19-04:00    FB
# 473874  2020-06-10 15:25:13-04:00    FB
# 473875  2020-06-10 11:33:26-04:00    FB
# 473876  2020-06-10 00:52:01-04:00    FB
# 473877  2020-06-10 00:28:00-04:00    FB

# %% [markdown]
# ## --- TEMPORARILY SET THE ANALYZER'S DATAFRAME TO THE FILTERED DATA ---

# %%
# This is the crucial step to make your existing methods work
analyzer.df = meta_df

# %% [markdown]
# ### run all analysis methods directly on the 'analyzer' object

# %% [markdown]
# ### They will now operate on the 'meta_df' because analyzer.df points to it

# %%
print("\n--- Descriptive Statistics for Headline lengths ---")
analyzer.textual_lengths() # Now this will work on the filtered data
analyzer.descriptive_statistics()

print("\n--- Headline Length Visualization ---")
analyzer.headline_length_visualization()

print("\n--- Articles per Publisher Analysis ---")
analyzer.articles_per_publisher()
analyzer.top_publishers()
analyzer.publisher_visualization()

print("\n--- Date-Based Analyses ---")
analyzer.prepare_dates() # This will prepare dates for the filtered data
analyzer.articles_by_day_of_week()
analyzer.articles_over_time(resampling_freq='D')
analyzer.articles_by_month()
analyzer.articles_by_hour()
# Out:
# --- Descriptive Statistics for Headline lengths ---
# Headline lengths calculated successfully.
#
# Descriptive Statistics for Headline Lengths:
# count    380.000000
# mean      13.294737
# std        6.789133
# min        5.000000
# 25%        9.000000
# 50%       12.000000
# 75%       14.000000
# max       44.000000
# Name: headline_length, dtype: float64
#
# --- Headline Length Visualization ---
# Headline length visualization displayed.
#
# --- Articles per Publisher Analysis ---
# Articles per publisher calculated successfully.
#
# Top 10 Publishers:
# publisher
# Benzinga Newsdesk    102
# Neer Varshney         56
# Shivdeep Dhaliwal     29
# IAM Newswire          22
# JJ Kinahan            21
# Vick Meyer            20
# Lisa Levin            19
# Benzinga Insights     16
# Wayne Duggan          12
# Jayson Derrick         9
# Name: count, dtype: int64
# Publisher visualization displayed.
#
# --- Date-Based Analyses ---
# Date column 'date' processed successfully.
# Articles by day of week visualization displayed.
# Articles over time (D frequency) visualization displayed.
# Articles by month visualization displayed.
# Articles by hour visualization displayed.

# %% [markdown]
# # --- IMPORTANT: RESTORE THE ORIGINAL DATAFRAME NEED IT LATER ---

# %%
analyzer.df = original_df
print("\nAnalyzer's DataFrame restored to original full dataset.")
# Out:
# Analyzer's DataFrame restored to original full dataset.
