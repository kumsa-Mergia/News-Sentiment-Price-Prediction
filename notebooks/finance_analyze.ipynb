# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
from stock_analyzer import StockAnalyzer

# %% [markdown]
# # Calculate technical indicators for APPLE

# %%
apple = StockAnalyzer('../Data/yfinance_data/AAPL_historical_data.csv')
# Calculate technical indicators
data_with_indicators = apple.calculate_technical_indicators()
# Plot results
print("\n APPLE STOCK ANALYSIS")
apple.plot_stock_data(data_with_indicators)
# Out:
#  APPLE STOCK ANALYSIS
